# %% [markdown]
# Обязательная часть
# Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: <дата> - <заголовок> - <ссылка>.

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import time
time.sleep(0.2)

# %%
import pandas as pd

# %%
keywords = ['python', 'парсинг']

# %%
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')

# %%
posts = soup.find_all('article', class_='post')
posts
# Out:
# [<article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/RalfHacker/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/ae0/022/8cc/ae00228cc341536b0ea9734daf7f4b91.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">RalfHacker</span>
#  </a>
#  <span class="post__time">сегодня в 18:08</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/516842/">HackTheBox. Прохождение Quick. QUIC HTTP/3, XSLT инъекция, Race condition</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
# ...

# %%
for post in posts:
    post_id = post.parent.attrs.get('id')
  
    if not post_id:
        continue
    post_id = int(post_id.split('_')[-1])
    titles = post.find_all('h2', class_='post__title')
    time.sleep(0.2)
    for title in titles:
            title_lower = title.text.lower()
           # ищем вхождение хотя бы одного желаемого хаба
            if any([title_lower in desired for desired in keywords]):
                title_date = post.find('span', class_='post_time')
                title_title = post.find('h2', class_='post__title')
                title_element = title_element = post.find('a', class_='post__title_link')
                print(title_date.text, title_element.text, title_element.attrs.get('href'))

# %% [markdown]
# Обязательная часть
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>.

# %%
URL = 'https://digibody.avast.com/v1/web/leaks'

# %%
email = ['ka.kriukova@severstal.com']

# %%
res = requests.post(URL, json=email)

# %%
res
# Out:
# <Response [400]>
